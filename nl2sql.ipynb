# %% [markdown]
# # Natural Language to SQL
#
# In this notebook, we benchmark the opensource code generation large language models such as CodeLLAMA, Codestral,etc., by fine tuning the models to generate SQL queries from natural language and evaluate them on metrics such as Accuracy, MMLU, etc. The best model will be integrated to the app [GenoQuery](https://github.com/parthasarathydNU/protein-data-nlq).

# %%
# # Install Pytorch & other libraries
# !pip install torch tensorboard

# # Install Hugging Face libraries
# !pip install --upgrade \
#   transformers \
#   datasets \
#   accelerate \
#   evaluate \
#   bitsandbytes \
#   trl \
#   peft

# # install peft & trl from github
# !pip install git+https://github.com/huggingface/trl@a3c5b7178ac4f65569975efadc97db2f3749c65e --upgrade
# !pip install git+https://github.com/huggingface/peft@4a1559582281fc3c9283892caea8ccef1d6f5a4f --upgrade

# %%
# Install Pytorch & other libraries
# !pip install "torch==2.1.2" tensorboard

# Install Hugging Face libraries
# !pip install  --upgrade \
  "transformers==4.36.2" \
  "datasets==2.16.1" \
  "accelerate==0.26.1" \
  "evaluate==0.4.1" \
  "bitsandbytes==0.42.0" \
  # "trl==0.7.10" # \
  # "peft==0.7.1" \

# install peft & trl from github
# !pip install git+https://github.com/huggingface/trl@a3c5b7178ac4f65569975efadc97db2f3749c65e --upgrade
# !pip install git+https://github.com/huggingface/peft@4a1559582281fc3c9283892caea8ccef1d6f5a4f --upgrade
# Out:
# Requirement already satisfied: torch==2.1.2 in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (3.15.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2) (12.6.20)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.2) (1.3.0)
# Requirement already satisfied: transformers==4.36.2 in /usr/local/lib/python3.10/dist-packages (4.36.2)
# Requirement already satisfied: datasets==2.16.1 in /usr/local/lib/python3.10/dist-packages (2.16.1)
# Requirement already satisfied: accelerate==0.26.1 in /usr/local/lib/python3.10/dist-packages (0.26.1)
# Requirement already satisfied: evaluate==0.4.1 in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: bitsandbytes==0.42.0 in /usr/local/lib/python3.10/dist-packages (0.42.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (4.66.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (2.1.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.16.1) (2023.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (3.10.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (2.1.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.1) (0.18.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes==0.42.0) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.2) (2024.7.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==0.26.1) (12.6.20)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.16.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.16.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.16.1) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.16.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.26.1) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.26.1) (1.3.0)
# Collecting git+https://github.com/huggingface/trl@a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Cloning https://github.com/huggingface/trl (to revision a3c5b7178ac4f65569975efadc97db2f3749c65e) to /tmp/pip-req-build-5yyzw94k
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/trl /tmp/pip-req-build-5yyzw94k
#   Running command git rev-parse -q --verify 'sha^a3c5b7178ac4f65569975efadc97db2f3749c65e'
#   Running command git fetch -q https://github.com/huggingface/trl a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Running command git checkout -q a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Resolved https://github.com/huggingface/trl to commit a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.11.dev0) (2.1.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.11.dev0) (4.36.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.11.dev0) (1.26.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from trl==0.7.11.dev0) (0.26.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from trl==0.7.11.dev0) (2.16.1)
# Requirement already satisfied: tyro>=0.5.11 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.11.dev0) (0.8.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (3.15.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.11.dev0) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl==0.7.11.dev0) (12.6.20)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (0.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (4.66.5)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.11.dev0) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.11.dev0) (13.7.1)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.11.dev0) (1.7.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->trl==0.7.11.dev0) (5.9.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.11.dev0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.11.dev0) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.11.dev0) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.11.dev0) (2.1.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.11.dev0) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.11.dev0) (0.70.15)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.11.dev0) (3.10.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.11.dev0) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.11.dev0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.11.dev0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.11.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.11.dev0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.11.dev0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.11.dev0) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.11.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.11.dev0) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl==0.7.11.dev0) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.7.11.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.7.11.dev0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.7.11.dev0) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl==0.7.11.dev0) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.11.dev0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.7.11.dev0) (1.16.0)
# Collecting git+https://github.com/huggingface/peft@4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Cloning https://github.com/huggingface/peft (to revision 4a1559582281fc3c9283892caea8ccef1d6f5a4f) to /tmp/pip-req-build-5pdj4y_e
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft /tmp/pip-req-build-5pdj4y_e
#   Running command git rev-parse -q --verify 'sha^4a1559582281fc3c9283892caea8ccef1d6f5a4f'
#   Running command git fetch -q https://github.com/huggingface/peft 4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Running command git checkout -q 4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Resolved https://github.com/huggingface/peft to commit 4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (2.1.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (4.36.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (4.66.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (0.26.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (0.4.4)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2023.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft==0.7.2.dev0) (12.6.20)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.7.2.dev0) (2024.5.15)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.7.2.dev0) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft==0.7.2.dev0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft==0.7.2.dev0) (1.3.0)

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:32'

# Set the Hugging Face access token as an environment variable
os.environ['HUGGINGFACE_TOKEN'] = 'abc'

os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from trl import setup_chat_format

model_id = "meta-llama/Llama-2-7b-hf"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id, use_auth_token=os.getenv('HUGGINGFACE_TOKEN'))
model = AutoModelForCausalLM.from_pretrained(
                                              model_id,
                                              quantization_config=bnb_config,
                                              device_map={"":0},
                                              _attn_implementation="eager",
                                              use_auth_token=os.getenv('HUGGINGFACE_TOKEN'))

print("Tokenizer : ", tokenizer)

 # set chat template to OAI chatML, remove if you start from a fine-tuned model
model, tokenizer = setup_chat_format(model, tokenizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:690: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Tokenizer :  LlamaTokenizerFast(name_or_path='meta-llama/Llama-2-7b-hf', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
from peft import prepare_model_for_kbit_training

model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
from peft import LoraConfig, get_peft_model

config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules="all-linear",
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)
print_trainable_parameters(model)
# Out:
# trainable params: 19988480 || all params: 3520417792 || trainable%: 0.5677871542810337

# %% [markdown]
# # Dataset Loader

# %%
# !conda install -c conda-forge pyarrow -y
# Out:
# Channels:
#  - conda-forge
#  - rapidsai
#  - nvidia
#  - defaults
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - pyarrow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aws-c-auth-0.7.20          |       h5f1c8d9_0         103 KB  conda-forge
#     aws-c-cal-0.6.12           |       h2ba76a8_0          45 KB  conda-forge
#     aws-c-common-0.9.17        |       h4ab18f5_0         222 KB  conda-forge
#     aws-c-compression-0.2.18   |       h36a0aea_4          19 KB  conda-forge
#     aws-c-event-stream-0.4.2   |      h161de36_10          53 KB  conda-forge
#     aws-c-http-0.8.1           |      h63f54a0_13         191 KB  conda-forge
#     aws-c-io-0.14.8            |       h96d4d28_0         154 KB  conda-forge
#     aws-c-mqtt-0.10.4          |       hcc7299c_2         160 KB  conda-forge
#     aws-c-s3-0.5.9             |       h10bd90f_0         107 KB  conda-forge
#     aws-c-sdkutils-0.1.16      |       h36a0aea_0          54 KB  conda-forge
#     aws-checksums-0.1.18       |       h36a0aea_4          49 KB  conda-forge
#     aws-crt-cpp-0.26.8         |      h4f3a3cc_11         332 KB  conda-forge
#     aws-sdk-cpp-1.11.267       |       h51dfee4_8         3.5 MB  conda-forge
#     c-ares-1.33.0              |       ha66036c_0         178 KB  conda-forge
#     ca-certificates-2024.7.4   |       hbcca054_0         151 KB  conda-forge
#     certifi-2024.7.4           |     pyhd8ed1ab_0         156 KB  conda-forge
#     conda-24.7.1               |  py310hff52083_0         940 KB  conda-forge
#     glog-0.7.1                 |       hbabe93e_0         140 KB  conda-forge
#     grpcio-1.62.2              |  py310h1b8f574_0         980 KB  conda-forge
#     libabseil-20240116.2       | cxx17_he02047a_1         1.2 MB  conda-forge
#     libarrow-14.0.2            |  hefa796f_19_cpu         7.7 MB  conda-forge
#     libarrow-acero-14.0.2      |  hbabe93e_19_cpu         567 KB  conda-forge
#     libarrow-dataset-14.0.2    |  hbabe93e_19_cpu         571 KB  conda-forge
#     libarrow-flight-14.0.2     |  hc4f8a93_19_cpu         494 KB  conda-forge
#     libarrow-flight-sql-14.0.2 |  he4f5ca8_19_cpu         193 KB  conda-forge
#     libarrow-gandiva-14.0.2    |  hc1954e9_19_cpu         876 KB  conda-forge
#     libarrow-substrait-14.0.2  |  he4f5ca8_19_cpu         509 KB  conda-forge
#     libgoogle-cloud-2.23.0     |       h9be4e54_1         1.2 MB  conda-forge
#     libgoogle-cloud-storage-2.23.0|       hc7a4891_1         735 KB  conda-forge
#     libgrpc-1.62.2             |       h15f2491_0         7.0 MB  conda-forge
#     libparquet-14.0.2          |  hacf5a1f_19_cpu         1.1 MB  conda-forge
#     libprotobuf-4.25.3         |       h08a7969_0         2.7 MB  conda-forge
#     libre2-11-2023.09.01       |       h5a48ba9_2         227 KB  conda-forge
#     openssl-3.3.1              |       h4bc722e_2         2.8 MB  conda-forge
#     orc-2.0.0                  |       h17fec99_1        1005 KB  conda-forge
#     protobuf-4.25.3            |  py310ha8c1f0e_0         325 KB  conda-forge
#     pyarrow-14.0.2             |py310hd207890_19_cpu         4.2 MB  conda-forge
#     re2-2023.09.01             |       h7f4b329_2          26 KB  conda-forge
#     s2n-1.4.13                 |       he19d79f_0         339 KB  conda-forge
#     snappy-1.2.1               |       ha2e4443_0          41 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        41.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgoogle-cloud-s~ conda-forge/linux-64::libgoogle-cloud-storage-2.23.0-hc7a4891_1
#
# The following packages will be UPDATED:
#
#   aws-c-auth                              0.7.11-h0b4cabd_1 --> 0.7.20-h5f1c8d9_0
#   aws-c-cal                                0.6.9-h14ec70c_3 --> 0.6.12-h2ba76a8_0
#   aws-c-common                            0.9.12-hd590300_0 --> 0.9.17-h4ab18f5_0
#   aws-c-compression                       0.2.17-h572eabf_8 --> 0.2.18-h36a0aea_4
#   aws-c-event-stream                       0.4.1-h97bb272_2 --> 0.4.2-h161de36_10
#   aws-c-http                               0.8.0-h9129f04_2 --> 0.8.1-h63f54a0_13
#   aws-c-io                                0.14.0-hf8f278a_1 --> 0.14.8-h96d4d28_0
#   aws-c-mqtt                              0.10.1-h2b97f5f_0 --> 0.10.4-hcc7299c_2
#   aws-c-s3                                 0.4.9-hca09fc5_0 --> 0.5.9-h10bd90f_0
#   aws-c-sdkutils                          0.1.13-h572eabf_1 --> 0.1.16-h36a0aea_0
#   aws-checksums                           0.1.17-h572eabf_7 --> 0.1.18-h36a0aea_4
#   aws-crt-cpp                             0.26.0-h04327c0_8 --> 0.26.8-h4f3a3cc_11
#   aws-sdk-cpp                          1.11.210-hba3e011_10 --> 1.11.267-h51dfee4_8
#   c-ares                                  1.25.0-hd590300_0 --> 1.33.0-ha66036c_0
#   ca-certificates                       2024.6.2-hbcca054_0 --> 2024.7.4-hbcca054_0
#   certifi                             2024.2.2-pyhd8ed1ab_0 --> 2024.7.4-pyhd8ed1ab_0
#   conda                              24.5.0-py310hff52083_0 --> 24.7.1-py310hff52083_0
#   glog                                     0.6.0-h6f12383_0 --> 0.7.1-hbabe93e_0
#   grpcio                             1.59.3-py310h1b8f574_0 --> 1.62.2-py310h1b8f574_0
#   libabseil                     20230802.1-cxx17_h59595ed_0 --> 20240116.2-cxx17_he02047a_1
#   libarrow                            14.0.2-h84dd17c_3_cpu --> 14.0.2-hefa796f_19_cpu
#   libarrow-acero                      14.0.2-h59595ed_3_cpu --> 14.0.2-hbabe93e_19_cpu
#   libarrow-dataset                    14.0.2-h59595ed_3_cpu --> 14.0.2-hbabe93e_19_cpu
#   libarrow-flight                     14.0.2-h120cb0d_3_cpu --> 14.0.2-hc4f8a93_19_cpu
#   libarrow-flight-s~                  14.0.2-h61ff412_3_cpu --> 14.0.2-he4f5ca8_19_cpu
#   libarrow-gandiva                    14.0.2-hacb8726_3_cpu --> 14.0.2-hc1954e9_19_cpu
#   libarrow-substrait                  14.0.2-h61ff412_3_cpu --> 14.0.2-he4f5ca8_19_cpu
#   libgoogle-cloud                         2.12.0-h5206363_4 --> 2.23.0-h9be4e54_1
#   libgrpc                                 1.59.3-hd6c4280_0 --> 1.62.2-h15f2491_0
#   libparquet                          14.0.2-h352af49_3_cpu --> 14.0.2-hacf5a1f_19_cpu
#   libprotobuf                             4.24.4-hf27288f_0 --> 4.25.3-h08a7969_0
#   libre2-11                           2023.09.01-h7a70373_1 --> 2023.09.01-h5a48ba9_2
#   openssl                                  3.3.0-h4ab18f5_3 --> 3.3.1-h4bc722e_2
#   orc                                      1.9.2-h4b38347_0 --> 2.0.0-h17fec99_1
#   protobuf                           4.24.4-py310h620c231_0 --> 4.25.3-py310ha8c1f0e_0
#   pyarrow                        14.0.2-py310hf9e7431_3_cpu --> 14.0.2-py310hd207890_19_cpu
#   re2                                 2023.09.01-h7f4b329_1 --> 2023.09.01-h7f4b329_2
#   s2n                                      1.4.1-h06160fa_0 --> 1.4.13-he19d79f_0
#   snappy                                  1.1.10-hdb0a2a9_1 --> 1.2.1-ha2e4443_0
#
#
#
# Downloading and Extracting Packages:
# libarrow-14.0.2      | 7.7 MB    |                                       |   0%
# libgrpc-1.62.2       | 7.0 MB    |                                       |   0%
#
# pyarrow-14.0.2       | 4.2 MB    |                                       |   0%
#
#
# aws-sdk-cpp-1.11.267 | 3.5 MB    |                                       |   0%
#
#
#
# openssl-3.3.1        | 2.8 MB    |                                       |   0%
#
#
#
#
# libprotobuf-4.25.3   | 2.7 MB    |                                       |   0%
#
#
#
#
#
# libabseil-20240116.2 | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
# libgoogle-cloud-2.23 | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
# libparquet-14.0.2    | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# orc-2.0.0            | 1005 KB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 980 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# conda-24.7.1         | 940 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-gandiva-14. | 876 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 735 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-dataset-14. | 571 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-acero-14.0. | 567 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-substrait-1 | 509 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-flight-14.0 | 494 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s2n-1.4.13           | 339 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.26.8   | 332 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2023.09.01 | 227 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.9.17  | 222 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libarrow-14.0.2      | 7.7 MB    | 3                                     |   1%
#
#
#
# openssl-3.3.1        | 2.8 MB    | 4                                     |   1%
#
#
# aws-sdk-cpp-1.11.267 | 3.5 MB    | 1                                     |   0%
#
# pyarrow-14.0.2       | 4.2 MB    | 1                                     |   0%
# libarrow-14.0.2      | 7.7 MB    | #############9                        |  38%
#
#
#
# openssl-3.3.1        | 2.8 MB    | ###########################2          |  74%
#
#
# aws-sdk-cpp-1.11.267 | 3.5 MB    | ###################                   |  52%
#
# pyarrow-14.0.2       | 4.2 MB    | ###############2                      |  41%
# libarrow-14.0.2      | 7.7 MB    | ############################2         |  76%
#
#
#
#
# libprotobuf-4.25.3   | 2.7 MB    | 2                                     |   1%
#
#
#
#
#
# libabseil-20240116.2 | 1.2 MB    | 4                                     |   1%
#
#
#
#
# libprotobuf-4.25.3   | 2.7 MB    | ##################################9   |  94%
#
#
#
#
#
#
# libgoogle-cloud-2.23 | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
# libparquet-14.0.2    | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
# orc-2.0.0            | 1005 KB   | 5                                     |   2%
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 980 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-gandiva-14. | 876 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
# conda-24.7.1         | 940 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 735 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-dataset-14. | 571 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-acero-14.0. | 567 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-flight-14.0 | 494 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-substrait-1 | 509 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.26.8   | 332 KB    | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s2n-1.4.13           | 339 KB    | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.9.17  | 222 KB    | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2023.09.01 | 227 KB    | ##6                                   |   7%
#
#
#
# openssl-3.3.1        | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
# libabseil-20240116.2 | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
# libabseil-20240116.2 | 1.2 MB    | ##################################### | 100%
#
# pyarrow-14.0.2       | 4.2 MB    | ##################################### | 100%
#
# pyarrow-14.0.2       | 4.2 MB    | ##################################### | 100%
#
#
#
#
#
#
# libgoogle-cloud-2.23 | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
# libgoogle-cloud-2.23 | 1.2 MB    | ##################################### | 100%
#
#
#
#
# libprotobuf-4.25.3   | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libparquet-14.0.2    | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libparquet-14.0.2    | 1.1 MB    | ##################################### | 100%
#
#
# aws-sdk-cpp-1.11.267 | 3.5 MB    | ##################################### | 100%
#
#
# aws-sdk-cpp-1.11.267 | 3.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# orc-2.0.0            | 1005 KB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# orc-2.0.0            | 1005 KB   | ##################################### | 100%
# libarrow-14.0.2      | 7.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 735 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 735 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-gandiva-14. | 876 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-gandiva-14. | 876 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-dataset-14. | 571 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-dataset-14. | 571 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-acero-14.0. | 567 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-acero-14.0. | 567 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.26.8   | 332 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.26.8   | 332 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-flight-14.0 | 494 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-flight-14.0 | 494 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-substrait-1 | 509 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-substrait-1 | 509 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s2n-1.4.13           | 339 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s2n-1.4.13           | 339 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 980 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 980 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# conda-24.7.1         | 940 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# conda-24.7.1         | 940 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.9.17  | 222 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.9.17  | 222 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2023.09.01 | 227 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2023.09.01 | 227 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from datasets import load_dataset

# Convert dataset to OAI messages
system_message = """You are an text to SQL query translator. Users will ask you questions in English and you will generate a SQL query based on the provided SCHEMA.
SCHEMA:
{schema}"""

def create_conversation(sample):
    return {
    "messages": [
      {"role": "system", "content": system_message.format(schema=sample["context"])},
      {"role": "user", "content": sample["question"]},
      {"role": "assistant", "content": sample["answer"]}
    ]
  }

# Load dataset from the hub
dataset = load_dataset("b-mc2/sql-create-context", split="train")
dataset = dataset.shuffle().select(range(12500))

# Convert dataset to OAI messages
dataset = dataset.map(create_conversation, remove_columns=dataset.features,batched=False)
# split dataset into 10,000 training samples and 2,500 test samples
dataset = dataset.train_test_split(test_size=2500/12500)

print(dataset["train"][345]["messages"])

# save datasets to disk
dataset["train"].to_json("train_dataset.json", orient="records")
dataset["test"].to_json("test_dataset.json", orient="records")
# Out:
# Map:   0%|          | 0/12500 [00:00<?, ? examples/s]
# [{'content': 'You are an text to SQL query translator. Users will ask you questions in English and you will generate a SQL query based on the provided SCHEMA.\nSCHEMA:\nCREATE TABLE table_29163303_1 (partner VARCHAR, year VARCHAR, surface VARCHAR)', 'role': 'system'}, {'content': "Who was Bob Bryan's partner/s on a hard surface in 2003?", 'role': 'user'}, {'content': 'SELECT partner FROM table_29163303_1 WHERE year = 2003 AND surface = "Hard"', 'role': 'assistant'}]
# Creating json from Arrow format:   0%|          | 0/10 [00:00<?, ?ba/s]
# Creating json from Arrow format:   0%|          | 0/3 [00:00<?, ?ba/s]
# 1188896

# %%
from datasets import load_dataset

# Load jsonl data from disk
dataset = load_dataset("json", data_files="train_dataset.json", split="train")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# # Model Training

# %%
# import transformers

# # needed for gpt-neo-x tokenizer
# tokenizer.pad_token = tokenizer.eos_token

# trainer = transformers.Trainer(
#     model=model,
#     train_dataset=dataset["train"],
#     args=transformers.TrainingArguments(
#         per_device_train_batch_size=1,
#         gradient_accumulation_steps=4,
#         warmup_steps=2,
#         max_steps=10,
#         learning_rate=2e-4,
#         fp16=True,
#         logging_steps=1,
#         output_dir="outputs",
#         optim="paged_adamw_8bit"
#     ),
#     data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
# )
# model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
# trainer.train()

# %%
from transformers import TrainingArguments

args = TrainingArguments(
    output_dir="llama-7b-text-to-sql", # directory to save and repository id
    num_train_epochs=2,                     # number of training epochs
    per_device_train_batch_size=1,          # batch size per device during training
    gradient_accumulation_steps=4,          # number of steps before performing a backward/update pass
    gradient_checkpointing=True,            # use gradient checkpointing to save memory
    optim="adamw_torch_fused",              # use fused adamw optimizer
    logging_steps=5,                       # log every 10 steps
    save_strategy="epoch",                  # save checkpoint every epoch
    learning_rate=2e-4,                     # learning rate, based on QLoRA paper
    bf16=False,                              # use bfloat16 precision
    tf32=False,                              # use tf32 precision
    fp16=True,
    max_grad_norm=0.3,                      # max gradient norm based on QLoRA paper
    warmup_ratio=0.03,                      # warmup ratio based on QLoRA paper
    lr_scheduler_type="constant",           # use constant learning rate scheduler
    push_to_hub=False,                       # push model to hub
    report_to="tensorboard",                # report metrics to tensorboard
)

# %%
from trl import SFTTrainer

max_seq_length = 3072 # max sequence length for model and packing of the dataset

trainer = SFTTrainer(
    model=model,
    args=args,
    train_dataset=dataset,
    peft_config=config,
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    packing=True,
    dataset_kwargs={
        "add_special_tokens": False,  # We template with special tokens
        "append_concat_token": False, # No need to add additional separator token
    }
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
torch.cuda.empty_cache()

# %%
import gc
gc.collect()
# Out:
# 13300

# %%
# start training, the model will be automatically saved to the hub and the output directory
trainer.train()

# save model
# trainer.save_model()
trainer.save_state()
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='120' max='147' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/147 11:41:20 < 2:40:28, 0.00 it/s, Epoch 2.39/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.954800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.570900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.514000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.495200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.471000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.432300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.419800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.418100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.412300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.414300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.351800</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:141: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:141: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '

# %%
# start training, the model will be automatically saved to the hub and the output directory
trainer.train()

# save model
# trainer.save_model()
trainer.save_state()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='129' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [129/200 2:36:39 < 1:27:34, 0.01 it/s, Epoch 1.28/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.911900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.729100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.655200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.591800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.558000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.549200</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.537800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.523300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.513500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.515300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.501300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.487100</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.491600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.504900</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.485900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.491300</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.486500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.485800</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.481700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.466000</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.441000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.444300</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.440700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.438500</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.438900</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:141: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='143' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [143/200 2:53:53 < 1:10:17, 0.01 it/s, Epoch 1.42/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.911900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.729100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.655200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.591800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.558000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.549200</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.537800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.523300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.513500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.515300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.501300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.487100</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.491600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.504900</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.485900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.491300</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.486500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.485800</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.481700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.466000</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.441000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.444300</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.440700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.438500</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.438900</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.438800</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.435100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.435000</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# # Continue Training

# %%
# !pip install --upgrade trl
# Out:
# Requirement already satisfied: trl in /opt/conda/lib/python3.10/site-packages (0.7.11.dev0)
# Collecting trl
#   Using cached trl-0.9.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from trl) (2.1.2)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from trl) (4.44.1)
# Requirement already satisfied: numpy<2.0.0,>=1.18.2 in /opt/conda/lib/python3.10/site-packages (from trl) (1.26.4)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from trl) (0.33.0)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from trl) (2.16.1)
# Requirement already satisfied: tyro>=0.5.11 in /opt/conda/lib/python3.10/site-packages (from trl) (0.8.8)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (2023.10.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl) (4.66.4)
# Requirement already satisfied: docstring-parser>=0.16 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (1.7.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate->trl) (5.9.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (2.2.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (0.70.15)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (3.9.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.31.0->trl) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl) (2023.4)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Using cached trl-0.9.6-py3-none-any.whl (245 kB)
# Installing collected packages: trl
#   Attempting uninstall: trl
#     Found existing installation: trl 0.7.11.dev0
#     Uninstalling trl-0.7.11.dev0:
#       Successfully uninstalled trl-0.7.11.dev0
# Successfully installed trl-0.9.6

# %%
# from peft import PeftModel
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from trl import setup_chat_format

modelpath = "/kaggle/working/codestral-7b-text-to-sql/checkpoint-99"
tokenizer = AutoTokenizer.from_pretrained(modelpath)

# %%
model_id = "mistralai/Mistral-7B-Instruct-v0.2"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
# peft_model = PeftModelForCausalLM.from_pretrained(model_id=modelpath, model=model,is_trainable=True)

# %%
# peft_model.print_trainable_parameters()
# Out:
# trainable params: 20,971,520 || all params: 7,262,703,616 || trainable%: 0.2888

# %%
from peft import PeftModel, PeftConfig

config = PeftConfig.from_pretrained("/kaggle/working/codestral-7b-text-to-sql/checkpoint-99", use_auth_token=os.getenv('HUGGINGFACE_TOKEN'))
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             quantization_config=bnb_config,
                                             device_map={"":0},
                                             _attn_implementation="eager",
                                             use_auth_token=os.getenv('HUGGINGFACE_TOKEN'))

# Resize token embeddings to match the tokenizer's vocab size
model.resize_token_embeddings(len(tokenizer))
model.enable_input_require_grads()
model = PeftModel.from_pretrained(model,
                                 "/kaggle/working/codestral-7b-text-to-sql/checkpoint-99",
                                   is_trainable=True,
#                                   ignore_mismatched_sizes=True
                                 )


print(model.print_trainable_parameters())
# set chat template to OAI chatML, remove if you start from a fine-tuned model
model, tokenizer = setup_chat_format(model, tokenizer)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:469: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# trainable params: 20,971,520 || all params: 7,262,720,000 || trainable%: 0.28875572788156506
# None

# %%
from transformers import TrainingArguments

args = TrainingArguments(
    output_dir="codestral-7b-text-to-sql", # directory to save and repository id
    num_train_epochs=2,                     # number of training epochs
    per_device_train_batch_size=1,          # batch size per device during training
    gradient_accumulation_steps=4,          # number of steps before performing a backward/update pass
    gradient_checkpointing=True,            # use gradient checkpointing to save memory
    optim="adamw_torch_fused",              # use fused adamw optimizer
    logging_steps=10,                       # log every 10 steps
    save_strategy="epoch",                  # save checkpoint every epoch
    learning_rate=2e-4,                     # learning rate, based on QLoRA paper
    bf16=False,                              # use bfloat16 precision
    tf32=False,                              # use tf32 precision
    fp16=True,
    max_grad_norm=0.3,                      # max gradient norm based on QLoRA paper
    warmup_ratio=0.03,                      # warmup ratio based on QLoRA paper
    lr_scheduler_type="constant",           # use constant learning rate scheduler
    push_to_hub=False,                       # push model to hub
    report_to="tensorboard",                # report metrics to tensorboard
)

# %%
from trl import SFTTrainer

max_seq_length = 3072 # max sequence length for model and packing of the dataset

trainer = SFTTrainer(
    model=model,
    args=args,
    train_dataset=dataset,
    peft_config=config,
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    packing=True,
    dataset_kwargs={
        "add_special_tokens": False,  # We template with special tokens
        "append_concat_token": False, # No need to add additional separator token
    }
)
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_seq_length, packing, dataset_kwargs. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:192: UserWarning: You passed a `packing` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:280: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:366: UserWarning: You passed a `dataset_kwargs` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Generating train split: 0 examples [00:00, ? examples/s]
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:408: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %%
trainer.train(resume_from_checkpoint=modelpath)

# %%
# trainer.save_model()
trainer.save_state()

# %% [markdown]
# ## Model Inference
#
# Load the fine tuned model.
# * Load the base model
# * Add the fine tuned adapter layers

# %%
model = PeftModel.from_pretrained(model,
                                 "llama-7b-text-to-sql/checkpoint-100",
                                   is_trainable=False,
#                                   ignore_mismatched_sizes=True
                                 )


pipe = pipeline("text-generation",
                model=model,
                tokenizer=tokenizer,
                max_new_tokens=200,
)

# %%
prompt = <INST>

print(pipe(prompt)[0]['generated_text'])
